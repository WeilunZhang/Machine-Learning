# %%
import seaborn as sns

datatitan = sns.load_dataset("titanic")

g = sns.lmplot(x="age", y="survived", col="sex", hue="sex", data=datatitan,
               logistic=True)
g.set(xlim=(0, 85), ylim=(-.1, 1.1))
